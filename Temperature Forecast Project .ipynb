# %% [markdown]
# # ==============================================================
# # Name - Abhishek Kumar.
# # Batch Number -  DS2309.
# # ==============================================================

# %% [markdown]
# # **********************************************************************************************
# # Project Name:- Temperature Forecast Project using ML
# # **********************************************************************************************

# %% [markdown]
# ## Project Description
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.

# %% [markdown]
# Attribute Information:
# For more information, read [Cho et al, 2020].
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %% [markdown]
# * models that can predict the minimum temperature for the next day and the maximum temperature for the next day based on the details provided in the dataset.

# %% [markdown]
# # Dataset Link-
#
# https://github.com/dsrscientist/Dataset2/blob/main/temperature.csv

# %% [markdown]
# # Importing Important Libraries.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\ASHISH\Downloads\temperature.csv")

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
# Date column is act as object, so convert it into datetime datatype.
df['Date']=pd.to_datetime(df['Date'])

# %% [markdown]
# ### Extracting Date,Month and Year from Date column

# %%
df['Day']=df['Date'].dt.day
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year

# %%
df.drop(columns=['Date'],inplace=True)

# %%
df.columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
print('Number of Rows :',df.shape[0])
print('Number of Columns :',df.shape[1])
# Out:
# Number of Rows : 7752
# Number of Columns : 27

# %% [markdown]
# # Exploratory Data Analysis

# %%
# This will check if any duplicate Value
df.duplicated().sum()
# Out:
# 0

# %%
#check if any whitespace, 'NA' or '-' exist in dataset.
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %% [markdown]
# Comment:
# * No Duplicate entry in dataset.
# * No whitespace, NA, '-' exist in dataset.

# %% [markdown]
# ## Cheking Null Values in  Dataset

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull().sum().to_frame(),annot=True,cmap='viridis')
print(df.isnull().sum())
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# Day                  2
# Month                2
# Year                 2
# dtype: int64

# %% [markdown]
# # Handling Null Values.
# ## Filling Null Values with Zeros.

# %%
# filling nulls with zeros because dataset have numerical values.
df.fillna(0, inplace=True)

# %%
# Again checking NUll values
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Day                 0
# Month               0
# Year                0
# dtype: int64

# %% [markdown]
# Comment -
# * Null problem is shorted.

# %% [markdown]
# # Univariate Analysis

# %%
# Plotting histogram for present_Tmax and present_Tmin variables
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Present_Tmin'],kde=True,color='b')
plt.subplot(1,2,2)
sns.histplot(df['Present_Tmax'],kde=True,color='r')
plt.show()

# %% [markdown]
# Comment-
# * Maximum Temperature is in range of ('21 - 38').
# * Minimum Temeperature is in range of ('14 - 30')

# %%
sns.histplot(df['Solar radiation'],kde=True,color='y')
plt.show()

# %% [markdown]
# * Solar radiation range is (4250 - 6000)

# %%
sns.histplot(df['station'],kde=True,color='g')
plt.show()

# %%
# Plotting histogram for NEXT_Tmax and NEXT_Tmin variables
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Next_Tmin'],kde=True,color='c')
plt.subplot(1,2,2)
sns.histplot(df['Next_Tmax'],kde=True,color='m')
plt.show()

# %% [markdown]
# Comment-
# * Next Day Maximum Temperature is in range of ('19 - 38').
# * Next Day Minimum Temeperature is in range of ('13 - 30')

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Year')
plt.xlabel('Year', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.xticks( fontsize=12)
plt.show()

# %% [markdown]
# * Ratio of Average Temperature is Equal in Every Year.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# * Temperature variation between Present Tmax And Tmin

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=df, x='Present_Tmax', y='Present_Tmin',color='r')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, y='Solar radiation',x='Year',color='c')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df,x='Year', y='Present_Tmin',color='g')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df,x='Year', y='Present_Tmax',color='orange')
plt.show()

# %% [markdown]
# Comment -
# * Here Maximum And Minimum Temperature is not vary yearly.

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                    count         mean         std          min          25%  \
# station           7752.0    12.996646    7.213660     0.000000     7.000000
# Present_Tmax      7752.0    29.499407    4.083116     0.000000    27.700000
# Present_Tmin      7752.0    23.015338    3.256071     0.000000    21.600000
# LDAPS_RHmin       7752.0    56.210230   15.618676     0.000000    45.735368
# LDAPS_RHmax       7752.0    87.519784   11.227876     0.000000    84.038809
# LDAPS_Tmax_lapse  7752.0    29.326939    4.123757     0.000000    27.601014
# LDAPS_Tmin_lapse  7752.0    23.285106    3.277967     0.000000    22.032374
# LDAPS_WS          7752.0     7.029203    2.281613     0.000000     5.647741
# LDAPS_LH          7752.0    61.900288   34.120103   -13.603212    36.776474
# LDAPS_CC1         7752.0     0.365206    0.263668     0.000000     0.141643
# LDAPS_CC2         7752.0     0.352635    0.259164     0.000000     0.136090
# LDAPS_CC3         7752.0     0.315323    0.251090     0.000000     0.097389
# LDAPS_CC4         7752.0     0.296297    0.254803     0.000000     0.077967
# LDAPS_PPT1        7752.0     0.586267    1.937198     0.000000     0.000000
# LDAPS_PPT2        7752.0     0.480310    1.754900     0.000000     0.000000
# LDAPS_PPT3        7752.0     0.275508    1.156495     0.000000     0.000000
# LDAPS_PPT4        7752.0     0.266801    1.200654     0.000000     0.000000
# lat               7752.0    37.544722    0.050352    37.456200    37.510200
# lon               7752.0   126.991397    0.079435   126.826000   126.937000
# DEM               7752.0    61.867972   54.279780    12.370000    28.700000
# Slope             7752.0     1.257048    1.370444     0.098475     0.271300
# Solar radiation   7752.0  5341.502803  429.158867  4329.520508  4999.018555
# Next_Tmax         7752.0    30.169440    3.596114     0.000000    28.200000
# Next_Tmin         7752.0    22.852348    2.827042     0.000000    21.300000
# Day               7752.0    16.366744    8.244461     0.000000     8.000000
# Month             7752.0     7.078818    2.240962     0.000000     7.000000
# Year              7752.0  2014.480134   32.394355     0.000000  2014.000000
#
#                           50%          75%          max
# station             13.000000    19.000000    25.000000
# Present_Tmax        29.900000    32.000000    37.600000
# Present_Tmin        23.400000    24.900000    29.900000
# LDAPS_RHmin         54.828714    67.038254    98.524734
# LDAPS_RHmax         89.699505    93.704500   100.000153
# LDAPS_Tmax_lapse    29.662273    31.683819    38.542255
# LDAPS_Tmin_lapse    23.735942    25.134000    29.619342
# LDAPS_WS             6.531345     8.007471    21.857621
# LDAPS_LH            56.487289    83.904586   213.414006
# LDAPS_CC1            0.312156     0.571696     0.967277
# LDAPS_CC2            0.309148     0.554963     0.968353
# LDAPS_CC3            0.258831     0.494007     0.983789
# LDAPS_CC4            0.224420     0.497230     0.974710
# LDAPS_PPT1           0.000000     0.049122    23.701544
# LDAPS_PPT2           0.000000     0.016748    21.621661
# LDAPS_PPT3           0.000000     0.007231    15.841235
# LDAPS_PPT4           0.000000     0.000000    16.655469
# lat                 37.550700    37.577600    37.645000
# lon                126.995000   127.042000   127.135000
# DEM                 45.716000    59.832400   212.335000
# Slope                0.618000     1.767800     5.178230
# Solar radiation   5436.345215  5728.316406  5992.895996
# Next_Tmax           30.500000    32.600000    38.900000
# Next_Tmin           23.100000    24.600000    29.800000
# Day                 16.000000    24.000000    31.000000
# Month                7.000000     8.000000    12.000000
# Year              2015.000000  2016.000000  2017.000000

# %% [markdown]
# * We can see that there is high possibility of outlier existence.

# %% [markdown]
# # Correlation between Data

# %%
plt.figure(figsize=(22,18))
sns.heatmap(df.corr(),annot=True,linewidths=1,linecolor='black',fmt=' .2f' )
# Out:
# <Axes: >

# %% [markdown]
# Comment -
# * Present_Tmax & Prent_Tmin is highly correlated to Target Variable.
# * LDAPS_Tmax_lapes & LDAPS_Tmin_lapes is also highly correlated to Target Variables.
# * LDAPS_cc1,LDAPS_cc2,LDAPS_cc3 & LDAPS_cc4 are negativity correlated to target variables.

# %%
plt.figure(figsize=(12,8))
df.corr()['Next_Tmax'].sort_values(ascending=False).drop(['Next_Tmax']).plot(kind='bar',color='k')
plt.xlabel('Features',fontsize=10)
plt.ylabel('Next_Tmax',fontsize=10)
plt.title('Correlation between Next_Tmax and features using bar plot',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
df.corr()['Next_Tmin'].sort_values(ascending=False).drop(['Next_Tmin']).plot(kind='bar',color='brown')
plt.xlabel('Features',fontsize=10)
plt.ylabel('Next_Tmin',fontsize=10)
plt.title('Correlation between Next_Tmin and features using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(12,30),facecolor='brown')
index=1
for column in df:
    if index <=27:
        ax = plt.subplot(9,3,index)
        sns.boxplot(df[column], palette='rainbow')
        plt.xlabel(column,fontsize=12)
    index+=1
plt.show()

# %% [markdown]
# # Removing of Outlier

# %%
from scipy.stats import zscore

# Specify the columns to remove outliers
columns_to_remove_outliers = [ 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','DEM', 'Slope',
       'Solar radiation', 'Month']

# Calculate z-scores for each specified column
z_scores = df[columns_to_remove_outliers].apply(zscore)

# Set a threshold for z-scores (e.g., 3)
threshold = 3

# Remove rows with z-scores beyond the threshold in any specified column
df1 = df[(z_scores.abs() < threshold).all(axis=1)]

# %% [markdown]
# # Checking Skewness of Dataset

# %%
plt.figure(figsize=(14,30), facecolor='brown')
plotnumber=1
for column in df:
    if plotnumber <=27:
        ax = plt.subplot(9,3,plotnumber)
        sns.distplot(df[column], color='r',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# station             -0.000115
# Present_Tmax        -3.402987
# Present_Tmin        -3.232442
# LDAPS_RHmin         -0.113889
# LDAPS_RHmax         -4.712138
# LDAPS_Tmax_lapse    -3.457452
# LDAPS_Tmin_lapse    -3.573353
# LDAPS_WS             1.163684
# LDAPS_LH             0.635208
# LDAPS_CC1            0.460727
# LDAPS_CC2            0.474379
# LDAPS_CC3            0.643064
# LDAPS_CC4            0.671739
# LDAPS_PPT1           5.395178
# LDAPS_PPT2           5.776835
# LDAPS_PPT3           6.458608
# LDAPS_PPT4           6.826930
# lat                  0.087062
# lon                 -0.285213
# DEM                  1.723257
# Slope                1.563020
# Solar radiation     -0.511210
# Next_Tmax           -2.213759
# Next_Tmin           -2.049088
# Day                  0.244656
# Month               -0.708304
# Year               -62.067548
# dtype: float64

# %% [markdown]
# * 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmax','LDAPS_Tmax_lapse',&,'LDAPS_Tmin_lapse' are left skewed.
# * 'LDAPS_WS', 'LDAPS_LH','LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#    'LDAPS_PPT1','LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4' are Right Skewed.

# %% [markdown]
# # Removing Skewness

# %%
from scipy.stats import boxcox

# Columns with left-skewed data containing zeros
left_skewed_columns = ['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse']
# Apply Box-Cox transformation
df[left_skewed_columns] = df[left_skewed_columns].apply(lambda x: boxcox(x + 1)[0])

# %%
# columns with right-skewed data containing zeros
right_skewed_columns =  ['LDAPS_WS', 'LDAPS_LH', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','Year']

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[right_skewed_columns] = scaler.fit_transform(df[right_skewed_columns].values)

# %% [markdown]
# # Spliting data into Feature and Target variable

# %%
feature_columns=['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
       'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
       'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
       'Solar radiation', 'Day', 'Month', 'Year']
label_columns=['Next_Tmax']
labelcolumn=['Next_Tmin']

# %%
X = df[feature_columns]
Y = df[labelcolumn]
y = df[label_columns]

# %% [markdown]
# # feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %% [markdown]
# # Varience_inflation_factor
# ### Checking Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif['Features'] = X.columns

# %%
vif
# Out:
#          VIF          Features
# 0   1.227522           station
# 1   2.948551      Present_Tmax
# 2   2.742564      Present_Tmin
# 3   6.506956       LDAPS_RHmin
# 4   2.903938       LDAPS_RHmax
# 5   5.738070  LDAPS_Tmax_lapse
# 6   6.649246  LDAPS_Tmin_lapse
# 7   1.356490          LDAPS_WS
# 8   1.540782          LDAPS_LH
# 9   5.143758         LDAPS_CC1
# 10  5.885115         LDAPS_CC2
# 11  5.429633         LDAPS_CC3
# 12  3.481549         LDAPS_CC4
# 13  2.484238        LDAPS_PPT1
# 14  2.285300        LDAPS_PPT2
# 15  1.772315        LDAPS_PPT3
# 16  1.882495        LDAPS_PPT4
# 17  1.225538               lat
# 18  1.173559               lon
# 19  3.090737               DEM
# 20  2.940996             Slope
# 21  1.456198   Solar radiation
# 22  1.277743               Day
# 23  1.159448             Month
# 24  1.128651              Year

# %% [markdown]
# * 1 < VIF < 5: Moderate multicollinearity. The variance of the coefficient is moderately inflated.
# * VIF > 5: High multicollinearity.

# %% [markdown]
# # Machine learning Model  Next_Tmin

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, r2_score

# %%
# Spliting the data for training & testing.
for i in range(0,200):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=i, test_size=.3)

# %%
X['LDAPS_LH'] = X['LDAPS_LH'].fillna(0)

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

# %%
dtr.fit(X_train, Y_train)

pred = dtr.predict(X_test)

# Evaluate the model using regression metrics
r2 = r2_score(Y_test, pred)

print("R-squared:", r2*100)
# Out:
# R-squared: 21.8713829788206

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train, Y_train)

pred2 = rfr.predict(X_test)

# Evaluate the model using regression metrics
R3 = r2_score(Y_test, pred2)

print("R-squared:", R3*100)
# Out:
# R-squared: 70.41571317822019

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
rf=LinearRegression()
rf.fit(X_train,Y_train)
pred3=rf.predict(X_test)
R4=r2_score(Y_test,pred3)
print("R-squared:", R4*100)
# Out:
# R-squared: 62.74110827708918

# %% [markdown]
# # XGBRegressor

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()

# %%
xgb.fit(X_train, Y_train)

pred4 = xgb.predict(X_test)

# Evaluate the model using regression metrics
R5 = r2_score(Y_test, pred4)

print("R-squared:", R5*100)
# Out:
# R-squared: 67.10393635318535

# %% [markdown]
# # ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()

# %%
etr.fit(X_train, Y_train)

pred5 = etr.predict(X_test)

# Evaluate the model using regression metrics
R6 = r2_score(Y_test, pred5)

print("R-squared:", R6*100)
# Out:
# R-squared: 69.85386816794306

# %%
from sklearn.ensemble import BaggingRegressor
br=BaggingRegressor()

# %%
br.fit(X_train, Y_train)

pred6 = br.predict(X_test)

# Evaluate the model using regression metrics
R7 = r2_score(Y_test, pred6)

print("R-squared:", R7*100)
# Out:
# R-squared: 65.34209045398443

# %% [markdown]
# # Cross Validation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    Y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,Y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,Y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,Y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,Y_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 0.7111006018916594
# Mean squared error : 2.340040564058469
# Root Mean Squared Error: 1.5297191127976628
#
#
#  R2 Score :
# 0.6927019078480414
# ==============================================================================================================
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 0.65176698194325
# Mean squared error : 2.241415033533964
# Root Mean Squared Error: 1.4971356096005344
#
#
#  R2 Score :
# 0.7056535796408975
# ==============================================================================================================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 1.0167669819432503
# Mean squared error : 5.9299226139294925
# Root Mean Squared Error: 2.435143243000192
#
#
#  R2 Score :
# 0.22127251387948277
# ==============================================================================================================
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 1.6850477133041806
# Mean squared error : 6.893888189041641
# Root Mean Squared Error: 2.6256214862469496
#
#
#  R2 Score :
# 0.09468292108269438
# ==============================================================================================================
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 0.7737510955773245
# Mean squared error : 2.4155605494580255
# Root Mean Squared Error: 1.5542073701594732
#
#
#  R2 Score :
# 0.6827844953941402
# ==============================================================================================================
#
#
#  Error of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) :
# Mean absolute error : 0.645483957193888
# Mean squared error : 2.5049984135056023
# Root Mean Squared Error: 1.582718677941725
#
#
#  R2 Score :
# 0.6710393635318534
# ==============================================================================================================

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[200,400],'gamma':np.arange(0,0.1),
              'booster' : ['gbtree','gblinear'], 'max_depth':[4,6],
              'eta' : [ 0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =5)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.659 total time=   0.8s
# [CV 2/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.599 total time=   0.9s
# [CV 3/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.590 total time=   0.8s
# [CV 4/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.567 total time=   0.9s
# [CV 5/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.670 total time=   0.9s
# [CV 1/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.686 total time=   1.8s
# [CV 2/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.621 total time=   1.8s
# [CV 3/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.629 total time=   1.8s
# [CV 4/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.601 total time=   1.8s
# [CV 5/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.704 total time=   1.8s
# [CV 1/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.671 total time=   2.3s
# [CV 2/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.592 total time=   2.3s
# [CV 3/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.621 total time=   2.4s
# [CV 4/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.568 total time=   2.7s
# [CV 5/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.674 total time=   2.7s
# [CV 1/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.704 total time=   4.9s
# [CV 2/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.609 total time=   4.7s
# [CV 3/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.661 total time=   5.0s
# [CV 4/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.599 total time=   5.2s
# [CV 5/5] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.694 total time=   6.0s
# [CV 1/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.716 total time=   1.0s
# [CV 2/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.676 total time=   0.9s
# [CV 3/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.649 total time=   1.0s
# [CV 4/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.629 total time=   1.0s
# [CV 5/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.715 total time=   1.1s
# [CV 1/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.713 total time=   2.5s
# [CV 2/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.681 total time=   2.1s
# [CV 3/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.634 total time=   2.1s
# [CV 4/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.632 total time=   1.9s
# [CV 5/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.715 total time=   1.9s
# [CV 1/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.715 total time=   2.5s
# [CV 2/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.654 total time=   2.5s
# [CV 3/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.682 total time=   2.6s
# [CV 4/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.626 total time=   2.5s
# [CV 5/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.701 total time=   2.5s
# [CV 1/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.716 total time=   5.1s
# [CV 2/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.657 total time=   4.9s
# [CV 3/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.683 total time=   4.7s
# [CV 4/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.629 total time=   4.6s
# [CV 5/5] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.703 total time=   4.5s
# [CV 1/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.287 total time=   0.4s
# [CV 2/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.277 total time=   0.4s
# [CV 3/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.246 total time=   0.4s
# [CV 4/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.256 total time=   0.4s
# [CV 5/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.302 total time=   0.4s
# [CV 1/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.399 total time=   0.9s
# [CV 2/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.374 total time=   0.9s
# [CV 3/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.341 total time=   0.9s
# [CV 4/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.351 total time=   0.9s
# [CV 5/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.408 total time=   0.9s
# [CV 1/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.287 total time=   0.4s
# [CV 2/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.277 total time=   0.4s
# [CV 3/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.246 total time=   0.4s
# [CV 4/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.255 total time=   0.5s
# [CV 5/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=200;, score=0.302 total time=   0.5s
# [CV 1/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.399 total time=   0.9s
# [CV 2/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.374 total time=   0.9s
# [CV 3/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.341 total time=   0.9s
# [CV 4/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.351 total time=   0.9s
# [CV 5/5] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.408 total time=   0.9s
# [CV 1/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.612 total time=   0.5s
# [CV 2/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.534 total time=   0.4s
# [CV 3/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.517 total time=   0.4s
# [CV 4/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.527 total time=   0.5s
# [CV 5/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=200;, score=0.589 total time=   0.4s
# [CV 1/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.647 total time=   0.9s
# [CV 2/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.553 total time=   0.9s
# [CV 3/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.541 total time=   0.9s
# [CV 4/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.551 total time=   0.9s
# [CV 5/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=4, n_estimators=400;, score=0.615 total time=   0.9s
# [CV 1/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.612 total time=   0.4s
# [CV 2/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.534 total time=   0.5s
# [CV 3/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.517 total time=   0.4s
# [CV 4/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.526 total time=   0.4s
# [CV 5/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=200;, score=0.589 total time=   0.4s
# [CV 1/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.647 total time=   0.9s
# [CV 2/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.553 total time=   0.8s
# [CV 3/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.542 total time=   0.9s
# [CV 4/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.550 total time=   0.8s
# [CV 5/5] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.615 total time=   0.9s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'booster': ['gbtree', 'gblinear'], 'eta': [0.01, 0.1],
#                          'gamma': array([0.]), 'max_depth': [4, 6],
#                          'n_estimators': [200, 400]},
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'booster': 'gbtree',
#  'eta': 0.1,
#  'gamma': 0.0,
#  'max_depth': 6,
#  'n_estimators': 400}

# %%
Final_mod =  XGBRegressor(n_estimators=400 , booster= 'gbtree', eta= 0.1, max_depth= 6, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
Y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,Y_pred))
print('Mean squared error :', mean_squared_error(Y_test,Y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,Y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,Y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 0.6049905726136775
# Mean squared error : 2.4704386482082996
# Root Mean Squared Error: 1.5717629109405462
#
#
#  R2 Score of Final Model :
# 0.6755778104734147

# %% [markdown]
# # Saving Model of NEXT Temperature Minimun

# %%
import joblib
joblib.dump(Final_mod,'Next_Tmin_Forecast_Final.pkl')
# Out:
# ['Next_Tmin_Forecast_Final.pkl']

# %% [markdown]
# # Prediction Based on Model

# %%
# Loading the saved model
Model = joblib.load("Next_Tmin_Forecast_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test).flatten()
predicted = np.array(Model.predict(X_test)).flatten()
df_Predicted = pd.DataFrame({"Actual Values": actual, "Predicted Values": predicted}, index=range(len(actual)))
df_Predicted
# Out:
#       Actual Values  Predicted Values
# 0              25.3         25.101547
# 1              20.4         20.094433
# 2              25.1         25.271885
# 3              25.3         25.812851
# 4              16.8         16.525845
# ...             ...               ...
# 2321           20.9         21.146801
# 2322           22.6         22.506691
# 2323           24.6         21.534725
# 2324           21.2         21.347273
# 2325           24.3         24.101856
#
# [2326 rows x 2 columns]

# %% [markdown]
# # Machine learning Model  Next_Tmax

# %%
# Spliting the data for training & testing.
for i in range(0,200):
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=i, test_size=.3)

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
etr = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gbr=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,etr,dtc,BR,adb,gbr,xgb]

for m in model:
    m.fit(X_train,y_train)
    m.score(X_train,y_train)
    max_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(y_test,max_pred))
    print('Mean squared error :', mean_squared_error(y_test,max_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,max_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(y_test,max_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 0.9009578675838346
# Mean squared error : 4.622733311263973
# Root Mean Squared Error: 2.1500542577488533
#
#
#  R2 Score :
# 0.6281461308539709
# ==============================================================================================================
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 0.7779092863284608
# Mean squared error : 3.9227358164230433
# Root Mean Squared Error: 1.9805897647981128
#
#
#  R2 Score :
# 0.6844541112894582
# ==============================================================================================================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 1.3158641444539985
# Mean squared error : 10.739110060189166
# Root Mean Squared Error: 3.277058141106008
#
#
#  R2 Score :
# 0.1361431953394483
# ==============================================================================================================
#
#
#  Error of  BaggingRegressor() :
# Mean absolute error : 1.0094110060189168
# Mean squared error : 5.344210189165951
# Root Mean Squared Error: 2.3117547856911536
#
#
#  R2 Score :
# 0.5701103432619126
# ==============================================================================================================
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 3.8104433977738954
# Mean squared error : 25.156413186581837
# Root Mean Squared Error: 5.01561692980852
#
#
#  R2 Score :
# -1.0235884156399417
# ==============================================================================================================
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 1.0480062639209449
# Mean squared error : 4.381813686829466
# Root Mean Squared Error: 2.093278215342974
#
#
#  R2 Score :
# 0.6475257680657667
# ==============================================================================================================
#
#
#  Error of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) :
# Mean absolute error : 0.8827091149800006
# Mean squared error : 4.74998790006606
# Root Mean Squared Error: 2.1794466958533443
#
#
#  R2 Score :
# 0.6179097386534214
# ==============================================================================================================

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
parameter={'n_estimators': [50, 100],
    'max_depth': [ 10, 20],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1, 2],
    }
gsc = GridSearchCV(ExtraTreesRegressor(),parameter,verbose =5)

# %%
gsc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.658 total time=   1.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.662 total time=   2.0s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.642 total time=   2.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.656 total time=   2.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.726 total time=   1.8s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.667 total time=   3.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.684 total time=   3.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.638 total time=   3.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.647 total time=   5.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.728 total time=   4.6s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.641 total time=   1.9s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.685 total time=   1.8s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.632 total time=   2.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.656 total time=   2.5s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.723 total time=   2.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.658 total time=   4.0s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.684 total time=   4.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.645 total time=   4.0s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.654 total time=   4.9s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.719 total time=   4.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.674 total time=   2.0s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.691 total time=   2.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.637 total time=   2.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.652 total time=   2.6s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.722 total time=   2.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.677 total time=   4.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.693 total time=   4.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.638 total time=   4.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.652 total time=   4.8s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.730 total time=   4.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.674 total time=   1.9s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.693 total time=   1.8s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.641 total time=   2.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.645 total time=   2.0s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.730 total time=   2.7s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.686 total time=   4.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.694 total time=   3.5s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.650 total time=   3.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.652 total time=   3.5s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.746 total time=   3.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.675 total time=   4.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.712 total time=   4.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.665 total time=   4.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.682 total time=   3.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.740 total time=   3.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.672 total time=   6.8s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.709 total time=   6.6s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.676 total time=   6.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.673 total time=   6.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.752 total time=   6.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.643 total time=   2.7s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.729 total time=   2.7s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.665 total time=   3.0s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.677 total time=   3.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=50;, score=0.767 total time=   3.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.668 total time=   6.6s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.715 total time=   6.8s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.673 total time=   6.7s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.679 total time=   7.9s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=100;, score=0.757 total time=  10.8s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.706 total time=   3.9s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.724 total time=   3.9s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.667 total time=   4.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.672 total time=   3.9s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.751 total time=   3.7s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.708 total time=   7.6s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.726 total time=   8.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.663 total time=   7.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.676 total time=   6.9s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.775 total time=   7.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.713 total time=   4.0s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.727 total time=   4.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.670 total time=   4.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.683 total time=   3.6s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=50;, score=0.766 total time=   3.6s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.699 total time=   6.7s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.725 total time=   5.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.663 total time=   5.7s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.679 total time=   5.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=100;, score=0.769 total time=   5.5s
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'max_depth': [10, 20], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [50, 100]},
#              verbose=5)

# %%
gsc.best_params_
# Out:
# {'max_depth': 20,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3,
#  'n_estimators': 50}

# %%
Final_mod =  ExtraTreesRegressor(max_depth= 20,min_samples_leaf= 2,min_samples_split= 3,n_estimators= 50)

Final_mod.fit(X_train,y_train)
max_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(y_test,max_pred))
print('Mean squared error :', mean_squared_error(y_test,max_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,max_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(y_test,max_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 0.7772336260457358
# Mean squared error : 3.922510932388764
# Root Mean Squared Error: 1.9805329919970442
#
#
#  R2 Score of Final Model :
# 0.6844722010196298

# %% [markdown]
# # Final Model Saving of Next_Tmax

# %%
import joblib
joblib.dump(Final_mod,'Next_Tmax_Forecast_Final.pkl')
# Out:
# ['Next_Tmax_Forecast_Final.pkl']

# %%
# Loading the saved model
Model = joblib.load("Next_Tmax_Forecast_Final.pkl")

# prediction  DataFrame
actual = np.array(y_test).flatten()
predicted1 = np.array(Model.predict(X_test))
df_Predicted1 = pd.DataFrame({"Actual Values":actual,"Predicted Values ":predicted1},index= range(len(actual)))
df_Predicted1
# Out:
#       Actual Values  Predicted Values
# 0              32.2          31.583333
# 1              24.2          24.452933
# 2              34.2          31.830498
# 3              29.3          31.567333
# 4              21.0          21.064333
# ...             ...                ...
# 2321           27.1          27.503000
# 2322           31.2          30.683933
# 2323           29.2          26.664000
# 2324           27.6          27.596538
# 2325           31.4          32.224571
#
# [2326 rows x 2 columns]

# %% [markdown]
# # ===========================THANKS===========================
